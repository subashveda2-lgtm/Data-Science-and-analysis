# %%
print("hello python")
# Out:
# hello python

# %%
print("my name is subash.I live in kathmandu,Nepal.I amd 30 yrs old")
# Out:
# my name is subash.I live in kathmandu,Nepal.I amd 30 yrs old

# %%
print("My name is subash./n I am 30 years old./n I live in kathmandu,Nepal")
# Out:
# My name is subash./n I am 30 years old./n I live in kathmandu,Nepal

# %%
print("hello " + " subash sitaula")
# Out:
# hello  subash sitaula

# %%
print("hello " + " subash sitaula")
# Out:
# hello  subash sitaula

# %%
number1 = 30
number2= 50

addition = number1 + number2
subtraction = number1 - number2
multiplication = number1 *number2
division = number1/number2

print("The add of two numbers is:", addition)
print("The subtraction of two numbers is:", subtraction)
print("the multiplication of two numbers is:", multiplication)
print("The division of two numbers is:", division)
# Out:
# The add of two numbers is: 80
# The subtraction of two numbers is: -20
# the multiplication of two numbers is: 1500
# The division of two numbers is: 0.6

# %%
num1= int(input("enter the first number:"))
num2=int(input("enter the second number:"))
sum= num1 + num2
sub= num1-num2
mul= num1*num2
div=num1/num2
print("the sum of two numbers is:", sum)
print("the sub of two numbers is:", sub)
print("the multiplication of two number is:",mul)
print("the division of two numbers is:",div)
# Out:
# the sum of two numbers is: 100
# the sub of two numbers is: 0
# the multiplication of two number is: 2500
# the division of two numbers is: 1.0

# %%
#------------Receipt System---------------
customer_name = "Subash Sitaula"
item_count = 4
item_price = 500
total_price = item_count * item_price
is_member = True
print("===========Receipt===========")
print("customer name:", customer_name)
print("item count:", item_count)
print("item price:", item_price)
print("Total price:", total_price)
print("membership status:", is_member)
# Out:
# ===========Receipt===========
# customer name: Subash Sitaula
# item count: 4
# item price: 500
# Total price: 2000
# membership status: True

# %%
customer_name= input("enter the custmoner name:")
item_count=int(input("enter the item count:"))
item_price=int(input("enter the item price:"))
total_price=item_count*item_price;
is_member=True
print("===========Receipt===========")
print("customer name:", customer_name)
print("item count:", item_count)
print("item price:", item_price)
print("Total price:", total_price)
print("membership status:", is_member)
# Out:
# ===========Receipt===========
# customer name: subash sitaula
# item count: 4
# item price: 200
# Total price: 800
# membership status: True

# %%
customer_name =input("enter the customer name:")
item=input("enter the item name:")
item1=input("enter the item name:")
item2=input("enter the item name:")
item_price=int(input("enter the item price:"))
item_price1=int(input("enter the item price"))
item_price2=int(input("enter the item price:"))
total_price=item_price + item_price1 + item_price2
print("-------------receipt-------------")
print("address: Kathmadu,Nepal")
print("Customer name:", customer_name)
print("item 1:",item)
print("item 2:",item1)
print("item 3:",item2)
print("item1 price:",item_price)
print("item2 price:",item_price1)
print("item2 price:",item_price2)
print ("total price:",total_price)
# Out:
# -------------receipt-------------
# address: Kathmadu,Nepal
# Customer name: Subash Sitaula
# item 1: apple
# item 2: orange
# item 3: banana
# item1 price: 380
# item2 price: 150
# item2 price: 120
# total price: 650

# %%
#-------password checker---------------
password = "admin123"
password = input("enter the password:")
if password == "admin123":
    print("password is correct. Access granted.")
else:
    print("password is incorrect: Access denied.")
# Out:
# password is correct. Access granted.

# %%
x = 'ram'
y = "555"
print(type(x))
print(type(y))
# Out:
# <class 'str'>
# <class 'str'>

# %%
word = "Programming"
print(word[:5])
print(word[-5:])
print(word[::2])
# Out:
# Progr
# mming
# Pormig

# %%
print("hello world")

# %%
total_bill = 300
if total_bill > 500:
    discount = total_bill * 0.10
elif total_bill > 200:
    print("You get a 5% discount.")
    discount = total_bill * 0.05
else:
    discount = 0
final = total_bill - discount
print("Final:", final)
# Out:
# You get a 5% discount.
# Final: 285.0

# %%
num = 15
if num % 3 == 0 and num % 5 == 0:
    print(num, "is divisible by both 3 and 5")
else:
    print(num, "is not divisible by both 3 and 5")
# Out:
# 15 is divisible by both 3 and 5

# %%
a = 5
b = 5
if a == b:
    print("Both numbers are equal")
else:
    print("Numbers are not equal")
# Out:
# Both numbers are equal

# %%
for i in range(1, 6):
    print("Hello", i)
# Out:
# Hello 1
# Hello 2
# Hello 3
# Hello 4
# Hello 5

# %%
i = 1
while i <= 5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(5, 0, -1):
    print(i)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
fact = 1
n = 5
for i in range(1, n+1):
    fact *= i
print("Factorial =", fact)
# Out:
# Factorial = 120

# %%
def greet(name):
    return f"Hello, {name}!"

print(greet("Sita"))
# Out:
# Hello, Sita!

# %%
def square(num):
    return num * num

print("Square of 4 is:", square(4))
# Out:
# Square of 4 is: 16

# %%
def largest(a, b):
    return a if a > b else b
print("Largest number is:", largest(10, 20))
# Out:
# Largest number is: 20

# %%
fruits = ["apple", "banana"]
fruits.append("grapes")
print(fruits)
# Out:
# ['apple', 'banana', 'grapes']

# %%
nums = [5, 3, 8, 1]
nums.sort()
print(nums)
# Out:
# [1, 3, 5, 8]

# %%
text = "python is programming language"
print(text[0:6])
# Out:
# python
