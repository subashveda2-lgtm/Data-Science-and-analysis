# %% [markdown]
#                                                  Machine Learning
#         Regression                                                         Classification
#         1. Linear Regression                                               1. logistic Regression
#         2.Polynomial Regression                                            2. Decision Tree Classifier
#         3.Decision Tree Regression                                         3. Random Forest Classifier
#         4.Random Forest Regression                                         4. RNN
#         5.XGBoost Regression                                               5. Support Vector Machine(SVM)
#
#         evaluation: R2, MAE, MSE, RMSE, Matrics                             Evaluation: Accuracy, Recall, Metrics, F1 Score
