# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
bmw = pd.read_csv(r"C:\Users\ssita\pythonclass\BMW sales data (2010-2024).csv")
bmw.head()
# Out:
#       Model  Year         Region  Color Fuel_Type Transmission  Engine_Size_L  \
# 0  5 Series  2016           Asia    Red    Petrol       Manual            3.5
# 1        i8  2013  North America    Red    Hybrid    Automatic            1.6
# 2  5 Series  2022  North America   Blue    Petrol    Automatic            4.5
# 3        X3  2024    Middle East   Blue    Petrol    Automatic            1.7
# 4  7 Series  2020  South America  Black    Diesel       Manual            2.1
#
#    Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# 0      151748      98740          8300                 High
# 1      121671      79219          3428                  Low
# 2       10991     113265          6994                  Low
# 3       27255      60971          4047                  Low
# 4      122131      49898          3080                  Low

# %%
bmw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 50000 non-null  object
#  1   Year                  50000 non-null  int64
#  2   Region                50000 non-null  object
#  3   Color                 50000 non-null  object
#  4   Fuel_Type             50000 non-null  object
#  5   Transmission          50000 non-null  object
#  6   Engine_Size_L         50000 non-null  float64
#  7   Mileage_KM            50000 non-null  int64
#  8   Price_USD             50000 non-null  int64
#  9   Sales_Volume          50000 non-null  int64
#  10  Sales_Classification  50000 non-null  object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 4.2+ MB

# %%
engine_size = bmw["Engine_Size_L"].value_counts()
engine_size
# Out:
# Engine_Size_L
# 3.8    1511
# 2.5    1486
# 4.5    1475
# 1.9    1471
# 2.6    1470
# 4.2    1468
# 2.7    1452
# 4.4    1452
# 3.5    1450
# 2.1    1448
# 4.7    1442
# 3.7    1437
# 2.3    1436
# 1.6    1432
# 3.1    1431
# 3.2    1426
# 2.9    1425
# 3.9    1425
# 4.3    1424
# 3.3    1423
# 1.8    1422
# 4.1    1421
# 3.0    1420
# 3.4    1419
# 1.7    1418
# 4.0    1418
# 2.0    1417
# 2.2    1406
# 4.6    1405
# 4.8    1391
# 2.4    1381
# 3.6    1381
# 2.8    1370
# 4.9    1314
# 5.0     723
# 1.5     710
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
engine_size.plot(kind="bar")
plt.title("Distribution of Engine Size")
plt.xlabel("Engine Size (L)")
plt.ylabel("Frequency")
plt.show()

# %%
model= bmw["Model"].value_counts()
model
# Out:
# Model
# 7 Series    4666
# i3          4618
# i8          4606
# 3 Series    4595
# 5 Series    4592
# X1          4570
# X3          4497
# X5          4487
# M5          4478
# X6          4478
# M3          4413
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
model.plot(kind="bar")
plt.title("Distribution of Bmw Model")
plt.xlabel("Model")
plt.ylabel("Frequency")
plt.show()

# %%
year=  bmw["Year"].value_counts()
year
# Out:
# Year
# 2022    3478
# 2024    3427
# 2019    3392
# 2021    3372
# 2016    3365
# 2015    3358
# 2014    3350
# 2012    3332
# 2010    3330
# 2013    3326
# 2017    3290
# 2018    3278
# 2011    3278
# 2023    3219
# 2020    3205
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
year.plot(kind="bar")
plt.title("Distribution Of Year")
plt.xlabel("Year")
plt.ylabel("Frequency")
plt.show()

# %%
region = bmw["Region"].value_counts()
region
# Out:
# Region
# Asia             8454
# Middle East      8373
# North America    8335
# Europe           8334
# Africa           8253
# South America    8251
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
region.plot(kind="bar")
plt.title("Distribution of Region")
plt.xlabel("Region")
plt.ylabel("Frequency")
plt.show()

# %%
color = bmw["Color"].value_counts()
color
# Out:
# Color
# Red       8463
# Silver    8350
# Grey      8348
# White     8304
# Black     8273
# Blue      8262
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
color.plot(kind="bar")
plt.title("Distribution of color")
plt.xlabel("Color")
plt.ylabel("Frequency")
plt.show()

# %%
fuel_type = bmw["Fuel_Type"].value_counts()
fuel_type
# Out:
# Fuel_Type
# Hybrid      12716
# Petrol      12550
# Electric    12471
# Diesel      12263
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
fuel_type.plot(kind="bar")
plt.title("Distribution of Fuel Type")
plt.xlabel("Fuel Type")
plt.ylabel("Fzrequency")
plt.show()

# %%
transmission = bmw["Transmission"].value_counts()
transmission
# Out:
# Transmission
# Manual       25154
# Automatic    24846
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
transmission.plot(kind="bar")
plt.title("Distribution of Transmission Type")
plt.xlabel("Transmission Type")
plt.ylabel("Frequency")
plt.show()

# %%
mileage = bmw["Mileage_KM"].value_counts()
mileage
# Out:
# Mileage_KM
# 136842    5
# 14113     4
# 175287    4
# 132490    4
# 162249    4
#          ..
# 56672     1
# 151030    1
# 147396    1
# 3379      1
# 27255     1
# Name: count, Length: 44347, dtype: int64

# %%
plt.figure(figsize=(10, 5))
plt.scatter(mileage.index, mileage.values)
plt.title("Distribution of Mileage")
plt.xlabel("Mileage (KM)")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(mileage.index, mileage.values)
plt.title("Distribution of Mileage")
plt.xlabel("Mileage")
plt.ylabel("Frequency")
plt.show()

# %%
price = bmw["Price_USD"].value_counts()
price
# Out:
# Price_USD
# 30948     6
# 109241    5
# 67539     5
# 99091     5
# 64270     5
#          ..
# 102778    1
# 55064     1
# 42926     1
# 49898     1
# 60971     1
# Name: count, Length: 38246, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.scatter(price.index, price.values)
plt.title("Distribution of Price")
plt.xlabel("Price (USD)")
plt.ylabel("Frequency")
plt.show()

# %%
sales = bmw["Sales_Volume"].value_counts()
sales
# Out:
# Sales_Volume
# 9502    16
# 1474    14
# 6867    14
# 6976    14
# 7867    13
#         ..
# 1282     1
# 761      1
# 9411     1
# 5463     1
# 9083     1
# Name: count, Length: 9845, dtype: int64

# %%
plt.figure(figsize=(10, 5))
plt.bar(sales.index, sales.values)
plt.title("Distribution of Sales Volume")
plt.xlabel("Sales Volume")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.scatter(sales.index, sales.values)
plt.title("Distribution of Sales Volume")
plt.xlabel("Sales Volume")
plt.ylabel("Frequency")
plt.show()

# %%
sales_classification = bmw["Sales_Classification"].value_counts()
sales_classification
# Out:
# Sales_Classification
# Low     34754
# High    15246
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
sales_classification.plot(kind="bar")
plt.title("Distribution of Sales Classification")
plt.xlabel("Sales Classification")
plt.ylabel("Frequency")
plt.show()

# %%
bmw.describe()
# Out:
#                Year  Engine_Size_L     Mileage_KM      Price_USD  Sales_Volume
# count  50000.000000   50000.000000   50000.000000   50000.000000  50000.000000
# mean    2017.015700       3.247180  100307.203140   75034.600900   5067.514680
# std        4.324459       1.009078   57941.509344   25998.248882   2856.767125
# min     2010.000000       1.500000       3.000000   30000.000000    100.000000
# 25%     2013.000000       2.400000   50178.000000   52434.750000   2588.000000
# 50%     2017.000000       3.200000  100388.500000   75011.500000   5087.000000
# 75%     2021.000000       4.100000  150630.250000   97628.250000   7537.250000
# max     2024.000000       5.000000  199996.000000  119998.000000   9999.000000

# %%
bmw.describe(include = "O")
# Out:
#            Model Region  Color Fuel_Type Transmission Sales_Classification
# count      50000  50000  50000     50000        50000                50000
# unique        11      6      6         4            2                    2
# top     7 Series   Asia    Red    Hybrid       Manual                  Low
# freq        4666   8454   8463     12716        25154                34754

# %%
bmw.head()
# Out:
#       Model  Year         Region  Color Fuel_Type Transmission  Engine_Size_L  \
# 0  5 Series  2016           Asia    Red    Petrol       Manual            3.5
# 1        i8  2013  North America    Red    Hybrid    Automatic            1.6
# 2  5 Series  2022  North America   Blue    Petrol    Automatic            4.5
# 3        X3  2024    Middle East   Blue    Petrol    Automatic            1.7
# 4  7 Series  2020  South America  Black    Diesel       Manual            2.1
#
#    Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# 0      151748      98740          8300                 High
# 1      121671      79219          3428                  Low
# 2       10991     113265          6994                  Low
# 3       27255      60971          4047                  Low
# 4      122131      49898          3080                  Low

# %%
#-------------------------making agg using groupby--------------------------
Sales_Volume = bmw.groupby("Engine_Size_L")["Sales_Volume"].agg(["max","min", "mean"])
Sales_Volume
# Out:
#                 max  min         mean
# Engine_Size_L
# 1.5            9986  105  5050.712676
# 1.6            9992  105  5084.282821
# 1.7            9993  105  5018.712271
# 1.8            9996  110  5054.186357
# 1.9            9992  101  5212.341264
# 2.0            9999  100  5104.055752
# 2.1            9998  111  5045.196823
# 2.2            9991  100  4995.962304
# 2.3            9993  104  5034.413649
# 2.4            9998  103  5113.764663
# 2.5            9999  107  5087.520861
# 2.6            9996  105  5050.059864
# 2.7            9999  105  5157.621901
# 2.8            9986  102  5029.425547
# 2.9            9996  104  5028.044912
# 3.0            9991  103  5154.494366
# 3.1            9995  123  5052.588400
# 3.2            9982  109  5256.128331
# 3.3            9992  101  4932.314828
# 3.4            9994  107  5226.571529
# 3.5            9997  101  5027.459310
# 3.6            9993  100  4950.882694
# 3.7            9999  135  5126.254697
# ...

# %%
Sales_Volume = bmw.groupby("Engine_Size_L")["Sales_Volume"].mean()
plt.figure(figsize=(10,5))
plt.scatter(Sales_Volume.index, Sales_Volume.values, color="blue", marker="o")
plt.title("Average Sales Volume by engine size")
plt.xlabel("Engine_Size_L")
plt.ylabel("Average Sales Volume")
plt.grid(True, linestyle="--", alpha=0.8)
plt.show()

# %%
Sales_Volume = bmw.groupby("Engine_Size_L")["Sales_Volume"].mean()
plt.figure(figsize=(10,5))
plt.plot(Sales_Volume.index, Sales_Volume.values, color="blue", marker="o")
plt.title("Average Sales Volume by engine size")
plt.xlabel("Engine_Size_L")
plt.ylabel("Average Sales Volume")
plt.grid(True, linestyle="--", alpha=0.8)
plt.show()

# %%
Sales_Volume = bmw.groupby("Engine_Size_L")["Sales_Volume"].mean()
plt.figure(figsize=(10,5))
plt.bar(Sales_Volume.index, Sales_Volume.values, color="blue")
plt.title("Average Sales Volume by engine size")
plt.xlabel("Engine_Size_L")
plt.ylabel("Average Sales Volume")
plt.show()

# %%
Sales_Volume = bmw.groupby("Engine_Size_L")["Sales_Volume"].mean()
plt.figure(figsize=(10,5))
plt.pie(Sales_Volume.values, labels=Sales_Volume.index, autopct="%1.1f%%")
plt.title("Average Sales Volume by engine size")
plt.xlabel("Engine_Size_L")
plt.ylabel("Average Sales Volume")
plt.show()

# %%
bmw.head()
# Out:
#       Model  Year         Region  Color Fuel_Type Transmission  Engine_Size_L  \
# 0  5 Series  2016           Asia    Red    Petrol       Manual            3.5
# 1        i8  2013  North America    Red    Hybrid    Automatic            1.6
# 2  5 Series  2022  North America   Blue    Petrol    Automatic            4.5
# 3        X3  2024    Middle East   Blue    Petrol    Automatic            1.7
# 4  7 Series  2020  South America  Black    Diesel       Manual            2.1
#
#    Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# 0      151748      98740          8300                 High
# 1      121671      79219          3428                  Low
# 2       10991     113265          6994                  Low
# 3       27255      60971          4047                  Low
# 4      122131      49898          3080                  Low

# %%
Region = bmw.groupby("Region")["Price_USD"].agg(["max", "min", "mean"])
Region
# Out:
#                   max    min          mean
# Region
# Africa         119997  30002  74885.771598
# Asia           119997  30000  75554.925006
# Europe         119985  30028  74988.356851
# Middle East    119998  30008  74726.788487
# North America  119992  30032  75070.054709
# South America  119986  30020  74973.598837

# %%
Region = bmw.groupby("Region")["Price_USD"].mean()
plt.figure(figsize=(10,5))
plt.bar(Region.index, Region.values, color="green")
plt.title("Average Price of bmw across different regions")
plt.xlabel("Region")
plt.ylabel("Average Price (USD)")
plt.show()

# %%
Region = bmw.groupby("Region")["Price_USD"].mean()
plt.figure(figsize=(10,5))
plt.plot(Region.index, Region.values, color="green", marker="o")
plt.title("Average Price of bmw across different regions")
plt.xlabel("Region")
plt.ylabel("Average Price (USD)")
plt.grid(True, linestyle="--", alpha=0.8)
plt.show()

# %%
Region = bmw.groupby("Region")["Price_USD"].mean()
plt.figure(figsize=(10,5))
plt.scatter(Region.index, Region.values, color="green")
plt.title("Average Price of bmw across different regions")
plt.xlabel("Region")
plt.ylabel("Average Price (USD)")
plt.grid(True, linestyle="--", alpha=0.8)
plt.show()

# %%
Region = bmw.groupby("Region")["Price_USD"].mean()
plt.figure(figsize=(10,5))
plt.pie(Region.values, labels=Region.index,  autopct="%1.1f%%")
plt.title("Average Price of bmw across different regions")
plt.xlabel("Region")
plt.ylabel("Average Price (USD)")
plt.grid(True, linestyle="--", alpha=0.8)
plt.show()

# %%
Model = bmw.groupby("Model")["Mileage_KM"].agg(["max", "min", "mean"])
Model
# Out:
#              max  min           mean
# Model
# 3 Series  199900   36  100159.898368
# 5 Series  199956   21  101356.634582
# 7 Series  199991   23  100792.165881
# M3        199971   69   99729.770451
# M5        199822   42  102342.995757
# X1        199954   43  100375.682057
# X3        199996   58  100716.869024
# X5        199995   29  100259.739915
# X6        199935   55   99482.406208
# i3        199987    3   98734.766133
# i8        199955   57   99447.384933

# %%
Model = bmw.groupby("Model")["Mileage_KM"].mean()
plt.figure(figsize=(10,5))
plt.bar(Model.index, Model.values, color="green", alpha= 0.7)
plt.title("Average Mileage of bmw across different model")
plt.xlabel("Model")
plt.ylabel("Average Mileage (KM)")
plt.show()

# %%
Model = bmw.groupby("Model")["Mileage_KM"].mean()
plt.figure(figsize=(10,5))
plt.plot(Model.index, Model.values, color="green", marker="o")
plt.title("Average Mileage of bmw across different model")
plt.xlabel("Model")
plt.ylabel("Average Mileage (KM)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
Model = bmw.groupby("Model")["Mileage_KM"].mean()
plt.figure(figsize=(10,5))
plt.pie(Model.values, labels=Model.index, autopct="%1.1f%%")
plt.title("Average Mileage of bmw across different model")
plt.xlabel("Model")
plt.ylabel("Average Mileage (KM)")
plt.show()

# %%
Model = bmw.groupby("Model")["Mileage_KM"].mean()
plt.figure(figsize=(10,5))
plt.scatter(Model.index, Model.values, color="green", marker="o")
plt.title("Average Mileage of bmw across different model")
plt.xlabel("Model")
plt.ylabel("Average Mileage (KM)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
model = bmw.groupby("Model")["Price_USD"].agg(["max", "min","mean"])
model
# Out:
#              max    min          mean
# Model
# 3 Series  119994  30008  75566.233950
# 5 Series  119988  30002  75287.844077
# 7 Series  119978  30021  75570.196742
# M3        119960  30037  74841.588715
# M5        119946  30005  74474.930996
# X1        119996  30039  75262.219037
# X3        119954  30020  75016.616856
# X5        119973  30001  74708.116782
# X6        119997  30043  74434.600491
# i3        119965  30020  74800.268081
# i8        119998  30000  75366.270951

# %%
Model = bmw.groupby("Model")["Price_USD"].mean()
plt.figure(figsize=(10,5))
plt.plot(Model.index, Model.values, color="green", marker="o")
plt.title("Average Price of bmw across different model")
plt.xlabel("Model")
plt.ylabel("Average Price (USD)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
Model = bmw.groupby("Model")["Price_USD"].mean()
plt.figure(figsize=(10,5))
plt.barh(Model.index, Model.values, color="green", alpha= 0.7)
plt.title("Average Price of bmw across different model")
plt.xlabel("Model")
plt.ylabel("Average Price (USD)")
plt.show()

# %%
Model = bmw.groupby("Model")["Price_USD"].mean()
plt.figure(figsize=(10,5))
plt.scatter(Model.index, Model.values, color="green", marker="o")
plt.title("Average Price of bmw across different model")
plt.xlabel("Model")
plt.ylabel("Average Price (USD)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
Model = bmw.groupby("Model")["Price_USD"].mean()
plt.figure(figsize=(10,5))
plt.pie(Model.values, labels=Model.index, autopct="%1.1f%%")
plt.title("Average Price of bmw across different model")
plt.xlabel("Model")
plt.ylabel("Average Price (USD)")
plt.show()

# %%
model = bmw.groupby("Model")["Sales_Volume"].agg(["max", "min", "mean"])
model
# Out:
#            max  min         mean
# Model
# 3 Series  9999  103  5066.660065
# 5 Series  9999  101  5029.947517
# 7 Series  9999  103  5097.828118
# M3        9999  112  5064.512576
# M5        9998  100  5087.022778
# X1        9998  100  5121.676149
# X3        9999  103  5057.933956
# X5        9998  102  5061.232226
# X6        9996  101  5060.738276
# i3        9996  100  5009.495236
# i8        9998  101  5085.516934

# %%
Model = bmw.groupby("Model")["Sales_Volume"].mean()
plt.figure(figsize=(10,5))
plt.plot(Model.index, Model.values, color="green", marker="o")
plt.title("Average Sales Volume of bmw across different model")
plt.xlabel("Model")
plt.ylabel("Average Sales Volume")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
Model = bmw.groupby("Model")["Sales_Volume"].mean()
plt.figure(figsize=(10,5))
plt.bar(Model.index, Model.values, color="green", alpha= 0.7)
plt.title("Average Sales Volume of bmw across different model")
plt.xlabel("Model")
plt.ylabel("Average Sales Volume")
plt.show()

# %%
Model = bmw.groupby("Model")["Sales_Volume"].mean()
plt.figure(figsize=(10,5))
plt.scatter(Model.index, Model.values, color="green", marker="o")
plt.title("Average Sales Volume of bmw across different model")
plt.xlabel("Model")
plt.ylabel("Average Sales Volume")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
Model = bmw.groupby("Model")["Sales_Volume"].mean()
plt.figure(figsize=(10,5))
plt.pie(Model.values, labels=Model.index, autopct="%1.1f%%")
plt.title("Average Sales Volume of bmw across different model")
plt.xlabel("Model")
plt.ylabel("Average Sales Volume")
plt.show()

# %%
model = bmw.groupby("Model")["Engine_Size_L"].agg(["max", "min","mean"])
model
# Out:
#           max  min      mean
# Model
# 3 Series  5.0  1.5  3.252862
# 5 Series  5.0  1.5  3.243031
# 7 Series  5.0  1.5  3.258573
# M3        5.0  1.5  3.252957
# M5        5.0  1.5  3.249955
# X1        5.0  1.5  3.232013
# X3        5.0  1.5  3.234534
# X5        5.0  1.5  3.239737
# X6        5.0  1.5  3.251452
# i3        5.0  1.5  3.262689
# i8        5.0  1.5  3.240816

# %%
Model = bmw.groupby("Model")["Engine_Size_L"].mean()
plt.figure(figsize=(10,5))
plt.plot(Model.index, Model.values, color="green", marker="o")
plt.title("Average Engine Size of bmw across different model")
plt.xlabel("Model")
plt.ylabel("Average Engine Size (L)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
Model = bmw.groupby("Model")["Engine_Size_L"].mean()
plt.figure(figsize=(10,5))
plt.bar(Model.index, Model.values, color="green", alpha= 0.7)
plt.title("Average Engine Size of bmw across different model")
plt.xlabel("Model")
plt.ylabel("Average Engine Size (L)")
plt.show()

# %%
Model = bmw.groupby("Model")["Engine_Size_L"].mean()
plt.figure(figsize=(10,5))
plt.scatter(Model.index, Model.values, color="green", marker="o")
plt.title("Average Engine Size of bmw across different model")
plt.xlabel("Model")
plt.ylabel("Average Engine Size (L)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
Model = bmw.groupby("Model")["Engine_Size_L"].mean()
plt.figure(figsize=(10,5))
plt.pie(Model.values, labels=Model.index, autopct="%1.1f%%")
plt.title("Average Engine Size of bmw across different model")
plt.xlabel("Model")
plt.ylabel("Average Engine Size (L)")
plt.show()

# %%
bmw.head()
# Out:
#       Model  Year         Region  Color Fuel_Type Transmission  Engine_Size_L  \
# 0  5 Series  2016           Asia    Red    Petrol       Manual            3.5
# 1        i8  2013  North America    Red    Hybrid    Automatic            1.6
# 2  5 Series  2022  North America   Blue    Petrol    Automatic            4.5
# 3        X3  2024    Middle East   Blue    Petrol    Automatic            1.7
# 4  7 Series  2020  South America  Black    Diesel       Manual            2.1
#
#    Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# 0      151748      98740          8300                 High
# 1      121671      79219          3428                  Low
# 2       10991     113265          6994                  Low
# 3       27255      60971          4047                  Low
# 4      122131      49898          3080                  Low

# %%
Transmission= bmw.groupby("Transmission")["Engine_Size_L"].agg(["max", "min", "mean"])
Transmission
# Out:
#               max  min      mean
# Transmission
# Automatic     5.0  1.5  3.245802
# Manual        5.0  1.5  3.248541

# %%
Transmission = bmw.groupby("Transmission")["Engine_Size_L"].mean()
plt.figure(figsize=(10,5))
plt.pie(Transmission.values, labels=Transmission.index, autopct="%1.1f%%")
plt.title("Average Sales Volume of bmw across different transmission types")
plt.xlabel("Transmission")
plt.ylabel("Average engine size (l)")
plt.show()

# %%
Transmission = bmw.groupby("Transmission")["Engine_Size_L"].mean()
plt.figure(figsize=(10,5))
plt.plot(Transmission.index, Transmission.values, color="green", marker="o")
plt.title("Average Sales Volume of bmw across different transmission types")
plt.xlabel("Transmission")
plt.ylabel("Average Engine Size (l)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
Transmission = bmw.groupby("Transmission")["Engine_Size_L"].mean()
plt.figure(figsize=(10,5))
plt.scatter(Transmission.index, Transmission.values, color="green", marker="o")
plt.title("Average Sales Volume of bmw across different transmission types")
plt.xlabel("Transmission")
plt.ylabel("Average Engine Size (l)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
Transmission = bmw.groupby("Transmission")["Engine_Size_L"].mean()
plt.figure(figsize=(10,5))
plt.barh(Transmission.index, Transmission.values, color="green")
plt.title("Average Sales Volume of bmw across different transmission types")
plt.xlabel("Transmission")
plt.ylabel("Average Engine Size (l)")
plt.show()

# %%
Transmission = bmw.groupby("Transmission")["Mileage_KM"].agg(["max", "min", "mean"])
Transmission
# Out:
#                  max  min           mean
# Transmission
# Automatic     199996   21  101092.862191
# Manual        199995    3   99531.164149

# %%
Transmission = bmw.groupby("Transmission")["Mileage_KM"].mean()
plt.figure(figsize=(10,5))
plt.bar(Transmission.index, Transmission.values, color="green")
plt.title("Average Sales Volume of bmw across different transmission types")
plt.xlabel("Transmission")
plt.ylabel("Average Mileage (KM)")
plt.show()

# %%
Transmission = bmw.groupby("Transmission")["Mileage_KM"].mean()
plt.figure(figsize=(10,5))
plt.plot(Transmission.index, Transmission.values, color="green", marker="o")
plt.title("Average Sales Volume of bmw across different transmission types")
plt.xlabel("Transmission")
plt.ylabel("Average Mileage (KM)")
plt.grid(True, linestyle="--", alpha=0.8)
plt.show()

# %%
Transmission = bmw.groupby("Transmission")["Mileage_KM"].mean()
plt.figure(figsize=(10,5))
plt.scatter(Transmission.index, Transmission.values, color="green", marker="o")
plt.title("Average Sales Volume of bmw across different transmission types")
plt.xlabel("Transmission")
plt.ylabel("Average Mileage (KM)")
plt.grid(True, linestyle="--", alpha=0.8)
plt.show()

# %%
Transmission = bmw.groupby("Transmission")["Mileage_KM"].mean()
plt.figure(figsize=(10,5))
plt.pie(Transmission.values, labels=Transmission.index, autopct="%1.1f%%")
plt.title("Average Sales Volume of bmw across different transmission types")
plt.xlabel("Transmission")
plt.ylabel("Average Mileage (KM)")
plt.show()

# %%
Transmission = bmw.groupby("Transmission")["Sales_Volume"].agg(["max", "min", "mean"])
Transmission
# Out:
#                max  min         mean
# Transmission
# Automatic     9999  100  5071.788497
# Manual        9999  100  5063.293194

# %%
Transmission = bmw.groupby("Transmission")["Sales_Volume"].mean()
plt.figure(figsize=(10,5))
plt.plot(Transmission.index, Transmission.values, color="green", marker="o")
plt.title("Average Sales Volume of bmw across different transmission types")
plt.xlabel("Transmission")
plt.ylabel("Average Sales Volume")
plt.grid(True, linestyle="--", alpha=0.8)
plt.show()

# %%
Transmission = bmw.groupby("Transmission")["Sales_Volume"].mean()
plt.figure(figsize=(10,5))
plt.scatter(Transmission.index, Transmission.values, color="green", marker="o")
plt.title("Average Sales Volume of bmw across different transmission types")
plt.xlabel("Transmission")
plt.ylabel("Average Sales Volume")
plt.grid(True, linestyle="--", alpha=0.8)
plt.show()

# %%
Transmission = bmw.groupby("Transmission")["Sales_Volume"].mean()
plt.figure(figsize=(10,5))
plt.bar(Transmission.index, Transmission.values, color="green")
plt.title("Average Sales Volume of bmw across different transmission types")
plt.xlabel("Transmission")
plt.ylabel("Average Sales Volume")
plt.show()

# %%
Transmission = bmw.groupby("Transmission")["Sales_Volume"].mean()
plt.figure(figsize=(10,5))
plt.pie(Transmission.values, labels=Transmission.index,autopct="%1.1f%%")
plt.title("Average Sales Volume of bmw across different transmission types")
plt.xlabel("Transmission")
plt.ylabel("Average Sales Volume")
plt.show()

# %%
Transmission = bmw.groupby("Transmission")["Price_USD"].agg(["max", "min", "mean"])
Transmission
# Out:
#                  max    min          mean
# Transmission
# Automatic     119997  30000  75171.407631
# Manual        119998  30001  74899.469309

# %%
Transmission = bmw.groupby("Transmission")["Price_USD"].mean()
plt.figure(figsize=(10,5))
plt.scatter(Transmission.index, Transmission.values, color="green", marker="o")
plt.title("Average Price of bmw across different transmission types")
plt.xlabel("Transmission")
plt.ylabel("Average Price (USD)")
plt.grid(True, linestyle="--", alpha=0.8)
plt.show()

# %%
Transmission = bmw.groupby("Transmission")["Price_USD"].mean()
plt.figure(figsize=(10,5))
plt.plot(Transmission.index, Transmission.values, color="green", marker="o")
plt.title("Average Price of bmw across different transmission types")
plt.xlabel("Transmission")
plt.ylabel("Average Price (USD)")
plt.grid(True, linestyle="--", alpha=0.8)
plt.show()

# %%
Transmission = bmw.groupby("Transmission")["Price_USD"].mean()
plt.figure(figsize=(10,5))
plt.bar(Transmission.index, Transmission.values, color="green")
plt.title("Average Price of bmw across different transmission types")
plt.xlabel("Transmission")
plt.ylabel("Average Price (USD)")
plt.show()

# %%
Transmission = bmw.groupby("Transmission")["Price_USD"].mean()
plt.figure(figsize=(10,5))
plt.pie(Transmission.values, labels=Transmission.index, autopct="%1.1f%%")
plt.title("Average Price of bmw across different transmission types")
plt.xlabel("Transmission")
plt.ylabel("Average Price (USD)")
plt.show()

# %%
Sales_Classification = bmw.groupby("Sales_Classification")["Sales_Volume"].agg(["max", "min", "mean"])
Sales_Classification
# Out:
#                        max   min         mean
# Sales_Classification
# High                  9999  7000  8497.496327
# Low                   6999   100  3562.838954

# %%
bmw.head()
# Out:
#       Model  Year         Region  Color Fuel_Type Transmission  Engine_Size_L  \
# 0  5 Series  2016           Asia    Red    Petrol       Manual            3.5
# 1        i8  2013  North America    Red    Hybrid    Automatic            1.6
# 2  5 Series  2022  North America   Blue    Petrol    Automatic            4.5
# 3        X3  2024    Middle East   Blue    Petrol    Automatic            1.7
# 4  7 Series  2020  South America  Black    Diesel       Manual            2.1
#
#    Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# 0      151748      98740          8300                 High
# 1      121671      79219          3428                  Low
# 2       10991     113265          6994                  Low
# 3       27255      60971          4047                  Low
# 4      122131      49898          3080                  Low

# %%
Sales_Classification = bmw.groupby("Sales_Classification")["Sales_Volume"].mean()
plt.figure(figsize=(10,5))
plt.plot(Sales_Classification.index, Sales_Classification.values, color="green", marker="o")
plt.title("Average Sales Volume of bmw across different sales classifications")
plt.xlabel("Sales Classification")
plt.ylabel("Sales Volume")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
Sales_Classification = bmw.groupby("Sales_Classification")["Sales_Volume"].mean()
plt.figure(figsize=(10,5))
plt.bar(Sales_Classification.index, Sales_Classification.values, color="green")
plt.title("Average Sales Volume of bmw across different sales classifications")
plt.xlabel("Sales Classification")
plt.ylabel("Sales Volume")
plt.show()

# %%
Sales_Classification = bmw.groupby("Sales_Classification")["Sales_Volume"].mean()
plt.figure(figsize=(10,5))
plt.scatter(Sales_Classification.index, Sales_Classification.values, color="green", marker="o")
plt.title("Average Sales Volume of bmw across different sales classifications")
plt.xlabel("Sales Classification")
plt.ylabel("Sales Volume")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
Sales_Classification = bmw.groupby("Sales_Classification")["Sales_Volume"].mean()
plt.figure(figsize=(10,5))
plt.pie(Sales_Classification.values, labels=Sales_Classification.index, autopct="%1.1f%%")
plt.title("Average Sales Volume of bmw across different sales classifications")
plt.xlabel("Sales Classification")
plt.ylabel("Sales Volume")
plt.show()

# %%
Sales_Classification = bmw.groupby("Sales_Classification")["Price_USD"].agg(["max", "min","mean"])
Sales_Classification
# Out:
#                          max    min          mean
# Sales_Classification
# High                  119997  30000  74966.819756
# Low                   119998  30001  75064.335357

# %%
Sales_Classification = bmw.groupby("Sales_Classification")["Price_USD"].mean()
plt.figure(figsize=(10,5))
plt.plot(Sales_Classification.index, Sales_Classification.values, color="green", marker="o")
plt.title("Average Price of bmw across different sales classifications")
plt.xlabel("Sales Classification")
plt.ylabel("Average Price (USD)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
Sales_Classification = bmw.groupby("Sales_Classification")["Price_USD"].mean()
plt.figure(figsize=(10,5))
plt.scatter(Sales_Classification.index, Sales_Classification.values, color="green")
plt.title("Average Price of bmw across different sales classifications")
plt.xlabel("Sales Classification")
plt.ylabel("Average Price (USD)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
Sales_Classification = bmw.groupby("Sales_Classification")["Price_USD"].mean()
plt.figure(figsize=(10,5))
plt.bar(Sales_Classification.index, Sales_Classification.values, color="green")
plt.title("Average Price of bmw across different sales classifications")
plt.xlabel("Sales Classification")
plt.ylabel("Average Price (USD)")
plt.show()

# %%
Sales_Classification = bmw.groupby("Sales_Classification")["Price_USD"].mean()
plt.figure(figsize=(10,5))
plt.pie(Sales_Classification.values, labels=Sales_Classification.index, autopct="%1.1f%%")
plt.title("Average Price of bmw across different sales classifications")
plt.xlabel("Sales Classification")
plt.ylabel("Average Price (USD)")
plt.show()

# %%
Sales_classification = bmw.groupby("Sales_Classification")["Mileage_KM"].agg(["max", "min", "mean"])
Sales_Classification
# Out:
# Sales_Classification
# High    74966.819756
# Low     75064.335357
# Name: Price_USD, dtype: float64

# %%
Sales_Classification = bmw.groupby("Sales_Classification")["Mileage_KM"].mean()
plt.figure(figsize=(10,5))
plt.scatter(Sales_Classification.index, Sales_Classification.values, color="green", marker="o")
plt.title("Average Mileage of bmw across different sales classifications")
plt.xlabel("Sales Classification")
plt.ylabel("Average Mileage (KM)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
Sales_Classification = bmw.groupby("Sales_Classification")["Mileage_KM"].mean()
plt.figure(figsize=(10,5))
plt.plot(Sales_Classification.index, Sales_Classification.values, color="green", marker="o")
plt.title("Average Mileage of bmw across different sales classifications")
plt.xlabel("Sales Classification")
plt.ylabel("Average Mileage (KM)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
Sales_Classification = bmw.groupby("Sales_Classification")["Mileage_KM"].mean()
plt.figure(figsize=(10,5))
plt.bar(Sales_Classification.index, Sales_Classification.values, color="green")
plt.title("Average Mileage of bmw across different sales classifications")
plt.xlabel("Sales Classification")
plt.ylabel("Average Mileage (KM)")
plt.show()

# %%
Sales_Classification = bmw.groupby("Sales_Classification")["Mileage_KM"].mean()
plt.figure(figsize=(10,5))
plt.pie(Sales_Classification.values, labels=Sales_Classification.index, autopct="%1.1f%%")
plt.title("Average Mileage of bmw across different sales classifications")
plt.xlabel("Sales Classification")
plt.ylabel("Average Mileage (KM)")
plt.show()

# %%
Sales_Classification = bmw.groupby("Sales_Classification")["Engine_Size_L"].agg(["max", "min", "mean"])
Sales_Classification
# Out:
#                       max  min      mean
# Sales_Classification
# High                  5.0  1.5  3.244444
# Low                   5.0  1.5  3.248380

# %%
Sales_Classification = bmw.groupby("Sales_Classification")["Engine_Size_L"].mean()
plt.figure(figsize=(10,5))
plt.scatter(Sales_Classification.index, Sales_Classification.values, color="green", marker="o")
plt.title("Average Engine Size of bmw across different sales classifications")
plt.xlabel("Sales Classification")
plt.ylabel("Average Engine Size (L)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
Sales_Classification = bmw.groupby("Sales_Classification")["Engine_Size_L"].mean()
plt.figure(figsize=(10,5))
plt.plot(Sales_Classification.index, Sales_Classification.values, color="green", marker="o")
plt.title("Average Engine Size of bmw across different sales classifications")
plt.xlabel("Sales Classification")
plt.ylabel("Average Engine Size (L)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
Sales_Classification = bmw.groupby("Sales_Classification")["Engine_Size_L"].mean()
plt.figure(figsize=(10,5))
plt.bar(Sales_Classification.index, Sales_Classification.values, color = "green")
plt.title("Average Engine Size of bmw across different sales classifications")
plt.xlabel("Sales Classification")
plt.ylabel("Average Engine Size (L)")
plt.show()

# %%
Sales_Classification = bmw.groupby("Sales_Classification")["Engine_Size_L"].mean()
plt.figure(figsize=(10,5))
plt.pie(Sales_Classification.values, labels=Sales_Classification.index, autopct="%1.1f%%")
plt.title("Average Engine Size of bmw across different sales classifications")
plt.xlabel("Sales Classification")
plt.ylabel("Average Engine Size (L)")
plt.show()

# %%
Fuel_type = bmw.groupby("Fuel_Type")["Engine_Size_L"].agg(["max", "min", "mean"])
Fuel_type
# Out:
#            max  min      mean
# Fuel_Type
# Diesel     5.0  1.5  3.247615
# Electric   5.0  1.5  3.235787
# Hybrid     5.0  1.5  3.250692
# Petrol     5.0  1.5  3.254518

# %%
Fuel_type = bmw.groupby("Fuel_Type")["Mileage_KM"].agg(["max", "min", "mean"])
Fuel_type
# Out:
#               max  min           mean
# Fuel_Type
# Diesel     199995   42  100905.525483
# Electric   199991   48  100524.274477
# Hybrid     199996   23  100063.767144
# Petrol     199987    3   99753.514582

# %%
year = bmw.groupby("Year")["Price_USD"].agg(["max", "min", "mean"])
year
# Out:
#          max    min          mean
# Year
# 2010  119998  30075  75072.215916
# 2011  119978  30069  75293.276388
# 2012  119973  30055  75019.567227
# 2013  119954  30000  74535.908298
# 2014  119988  30061  74556.535224
# 2015  119970  30002  74049.552710
# 2016  119996  30021  75543.540862
# 2017  119986  30025  75173.147416
# 2018  119954  30005  75455.480781
# 2019  119997  30037  75194.426002
# 2020  119960  30010  75057.667083
# 2021  119981  30008  75399.277580
# 2022  119960  30001  74967.875503
# 2023  119988  30020  75194.004660
# 2024  119997  30054  75025.852933

# %%
year = bmw.groupby("Year")["Price_USD"].mean() 
plt.figure(figsize=(10,5))
plt.plot(year.index,year.values, marker="o", linestyle="-", color="green")
plt.title("Average Price of bmw over the years")
plt.xlabel("Year")
plt.ylabel("Average Price (USD)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(10,5))
bmw.boxplot(column ="Price_USD", by = "Transmission", grid = False)
plt.title("box plot by transmission type")
plt.suptitle("") # remove the default title to avoid overlap
plt.xlabel("Transmission")
plt.ylabel("Price (USD)")
plt.show()

# %%
# Corelation between price and mileage
plt.figure(figsize=(10,5))
plt.scatter(bmw["Mileage_KM"], bmw["Price_USD"], color="Purple", alpha=0.1)
plt.title("Correlation between price and mileage")
plt.xlabel("Mileage_KM")
plt.ylabel("Price (USD)")
plt.show()
